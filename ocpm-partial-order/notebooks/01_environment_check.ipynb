# %% [markdown]
# # Configurazione dell'ambiente
#
# ## Obiettivo
#
# Verificare che tutte le dipendenze necessarie siano installate e che i dataset siano disponibili nei percorsi previsti.
#
# ## Risultato atteso
#
# Tutti gli import devono completarsi senza errori e i file SQLite devono essere individuati correttamente.

# %%
import sys
import pm4py
import pandas as pd
import networkx as nx

print("Python:", sys.version)
print("PM4Py:", pm4py.__version__)
print("Pandas:", pd.__version__)
print("NetworkX:", nx.__version__)
# Out:
# ...
#
#   Welcome to PM4Py — Community Version
#   Open-Source License (AGPL v3)
#
#   📚 Docs & Examples:
#      https://processintelligence.solutions/pm4py
#
#   ⚖️  License: AGPL v3 — Commercial use requires open-sourcing your application.
#      Business use without open-sourcing? A commercial license is available:
#      https://processintelligence.solutions/pm4py#licensing
#
# ...
# Python: 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]
# PM4Py: 2.7.23.3
# Pandas: 3.0.5
# NetworkX: 3.6.1

# %%
from ocpm_partial_order.config import MAIN_DATASET_DB

print("Dataset principale:", MAIN_DATASET_DB)
print("File presente:", MAIN_DATASET_DB.exists())
# Out:
# Dataset principale: C:\Users\nicol\ocpm-partial-order\ocpm-partial-order\data\raw\order_management.sqlite
# File presente: True
